# %% [markdown]
# # Udemy Courses

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
udata = pd.read_csv(r'C:\Users\Acer\Downloads\Study\Data Sets\Udemy_courses.csv', parse_dates=['published_timestamp'])
udata.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
udata.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
udata.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
print('Udata Columns -', udata.shape[1])
print('Udata Rows -', udata.shape[0])
print('Udata Shape', udata.shape)
# Out:
# Udata Columns - 12
# Udata Rows - 3678
# Udata Shape (3678, 12)

# %%
udata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 262.3+ KB

# %%
print("Are there any missing values ?? ", udata.isnull().values.any())
# Out:
# Are there any missing values ??  False

# %%
udata['subject'].unique()
# or
udata.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
# Checking for free/unpaid courses
udata[udata.price == 0] # len(udata[udata.price == 0])
# or
udata[udata.is_paid == False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %%
udata.sort_values('num_subscribers', ascending=False)
# least 
# udata.sort_values('num_subscribers')
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1234     185526                             MicroStation - Células
# 886     1087466  Stop Creditors from Harassing you and Avoid Ba...
# 887     1058852            Learn to trade using technical analysis
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 777     1215926                Kickstarter success in 5 easy steps
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %%
udata[(udata.subject == 'Graphic Design') & (udata.price < 100)]
# Out:
#       course_id                                       course_title  \
# 1196    1197206                         Illustrator CC MasterClass
# 1198    1219520  Adobe Illustrator T-Shirt Design for Merch by ...
# 1202      28556              Discover How to Draw and paint Comics
# 1203     317278  Typographic Logos: Typography and Lettering fo...
# 1204     573064  Photoshop in Ease: Create World Amazing  Graph...
# ...         ...                                                ...
# 1793     456388           Adobe Photoshop CC | The Essential Guide
# 1794     955242   Learn to Composite a 2D Action Shot in Photoshop
# 1795     496430  Infographic Design: How To Create Your Own Inf...
# 1796     793246           Autodesk Inventor 2016 : Complete Guide
# 1797     547190               Amazing Graphic Design for Beginners
#
#                                                     url  is_paid  price  \
# 1196  https://www.udemy.com/illustrator-cc-masterclass/     True     95
# ...

# %%
# Number of python courses available
len(udata[udata.course_title.str.contains('Python')])
# Out:
# 29

# %%
# convert 'published_timestamp' dtype to to_datetime
udata['published_timestamp'] = pd.to_datetime(udata.published_timestamp)
udata.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# Year                                 int64
# dtype: object

# %%
# change published_timestamp dtype to year 
udata['Year']=udata['published_timestamp'].dt.year
udata[udata['Year'] == 2015]
# Out:
#       course_id                                       course_title  \
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8        476268  Options Trading 3 : Advanced Stock Profit and ...
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# 15       504036  Short Selling: Learn To Sell Stocks Before The...
# 17       564966  The Complete Chart Pattern Trading Course: A P...
# ...         ...                                                ...
# 3659     577796  Simple Javascript: Learn by Doing, Beginners W...
# 3667     523216  The Fastest Way to Create a Website Using Godaddy
# 3669     679992                  Building Better APIs with GraphQL
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3675     635248                      Learn and Build using Polymer
#
#                                                     url  is_paid  price  \
# 7     https://www.udemy.com/trading-chart-patterns-f...     True     95
# ...

# %%
udata.level.unique()
udata.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                                                                   url  \
# level
# All Levels          https://www.udemy.com/zombie-apocalypse-photos...
# Beginner Level                        https://www.udemy.com/zprzqgfl/
# Expert Level        https://www.udemy.com/working-capital-manageme...
# Intermediate Level           https://www.udemy.com/youtubedownloader/
#
#                     is_paid  price  num_subscribers  num_reviews  \
# level
# ...

# %%
# dealing with duplicate values
dup_udata = udata.duplicated().any()
print("Are there any duplicate values? ", dup_udata)
# Out:
# Are there any duplicate values?  True

# %%
udata = udata.drop_duplicates()
print(udata)
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
# verifying the above step
dup_udata = udata.duplicated().any()
print("Are there any duplicate values? ", dup_udata)
# Out:
# Are there any duplicate values?  False

# %%
udata['subject'].value_counts()
# or
udata.subject.value_counts().sort_values()
# Out:
# Graphic Design          602
# Musical Instruments     680
# Business Finance       1191
# Web Development        1199
# Name: subject, dtype: int64

# %%
sns.countplot(udata['subject'])
plt.xlabel('Subjects', fontsize = 12)
plt.xticks(rotation=40)
plt.ylabel('No. of courses per subject')
plt.yticks(rotation=360)
plt.show()
# Out:
# c:\users\acer\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
udata['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sns.countplot(udata['level'])
plt.xlabel('Levels', fontsize = 20)
plt.xticks(rotation=40)
plt.ylabel('Levesl Metric')
plt.yticks(rotation=360)
plt.show()
# Out:
# c:\users\acer\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
udata['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
sns.countplot(udata['is_paid'])
plt.xlabel('Difference b/w paid and unpaid courses', fontsize = 12)
plt.xticks(rotation=40)
plt.ylabel('Metrics')
plt.yticks(rotation=360)
plt.show()
# Out:
# c:\users\acer\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
udata.groupby(['is_paid']).mean()
# Out:
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration         Year
# is_paid
# False            2.210753  2015.500000
# True             4.271584  2015.424747

# %%
sns.barplot(x='is_paid', y='num_subscribers', data=udata)
# Out:
# <AxesSubplot:xlabel='is_paid', ylabel='num_subscribers'>

# %%
sns.barplot(x='level', y='num_subscribers', data=udata)
plt.xticks(rotation=45)
plt.show()

# %%
udata[udata['num_subscribers'].max()==udata['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
top10=udata.sort_values(by='num_subscribers',ascending=False).head(10)
sns.barplot(x='num_subscribers', y='course_title', data=top10)
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='course_title'>

# %%
sns.barplot(x='subject', y='num_reviews', data=udata)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Business Finance'),
#   Text(1, 0, 'Graphic Design'),
#   Text(2, 0, 'Musical Instruments'),
#   Text(3, 0, 'Web Development')])

# %%
sns.scatterplot(x='price', y='num_reviews', data=udata)
plt.figure(figsize=(15,3))

# %%
len(udata[udata['course_title'].str.contains('python', case=False)])
# Out:
# 29

# %%
vis_udata = udata[udata['course_title'].str.contains('python', case=False)].\
sort_values(by='num_subscribers',ascending=False).head(10)
vis_udata
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %%
sns.barplot(x='num_subscribers', y='course_title', data=vis_udata)
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='course_title'>

# %%
udata['Year']=udata['published_timestamp'].dt.year
udata
sns.countplot(x='Year', data=udata)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>
