# %% [markdown]
# # Weather data EDA

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wthr = pd.read_csv(r'C:\Users\Acer\Downloads\Study\Data Sets\weather_2012.csv', index_col=[0])
wthr.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %%
wthr.shape
# Out:
# (8784, 7)

# %%
wthr.dtypes
# Out:
# Temp (C)              float64
# Dew Point Temp (C)    float64
# Rel Hum (%)             int64
# Wind Spd (km/h)         int64
# Visibility (km)       float64
# Stn Press (kPa)       float64
# Weather                object
# dtype: object

# %%
wthr.index
# Out:
# Index(['2012-01-01 00:00:00', '2012-01-01 01:00:00', '2012-01-01 02:00:00',
#        '2012-01-01 03:00:00', '2012-01-01 04:00:00', '2012-01-01 05:00:00',
#        '2012-01-01 06:00:00', '2012-01-01 07:00:00', '2012-01-01 08:00:00',
#        '2012-01-01 09:00:00',
#        ...
#        '2012-12-31 14:00:00', '2012-12-31 15:00:00', '2012-12-31 16:00:00',
#        '2012-12-31 17:00:00', '2012-12-31 18:00:00', '2012-12-31 19:00:00',
#        '2012-12-31 20:00:00', '2012-12-31 21:00:00', '2012-12-31 22:00:00',
#        '2012-12-31 23:00:00'],
#       dtype='object', name='Date/Time', length=8784)

# %%
wthr.columns
# Out:
# Index(['Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)', 'Wind Spd (km/h)',
#        'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
wthr.count()
# Out:
# Temp (C)              8784
# Dew Point Temp (C)    8784
# Rel Hum (%)           8784
# Wind Spd (km/h)       8784
# Visibility (km)       8784
# Stn Press (kPa)       8784
# Weather               8784
# dtype: int64

# %%
wthr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8784 entries, 2012-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Temp (C)            8784 non-null   float64
#  1   Dew Point Temp (C)  8784 non-null   float64
#  2   Rel Hum (%)         8784 non-null   int64
#  3   Wind Spd (km/h)     8784 non-null   int64
#  4   Visibility (km)     8784 non-null   float64
#  5   Stn Press (kPa)     8784 non-null   float64
#  6   Weather             8784 non-null   object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 480.4+ KB

# %%
wthr["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
wthr['Wind Spd (km/h)'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
wthr['Wind Spd (km/h)'].nunique() # number of unique
# Out:
# 34

# %%
wthr.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# filtering Weather column for 'Clear' values
wthr[wthr.Weather == 'Clear' ]
# alternatively
wthr.groupby('Weather').get_group('Clear')
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-03 19:00:00     -16.9               -24.8           50
# 2012-01-05 18:00:00      -7.1               -14.4           56
# 2012-01-05 19:00:00      -9.2               -15.4           61
# 2012-01-05 20:00:00      -9.8               -15.7           62
# 2012-01-05 21:00:00      -9.0               -14.8           63
# ...                       ...                 ...          ...
# 2012-12-26 06:00:00     -13.4               -14.8           89
# 2012-12-28 10:00:00      -6.1                -8.6           82
# 2012-12-29 01:00:00     -11.9               -13.6           87
# 2012-12-29 02:00:00     -11.8               -13.1           90
# 2012-12-30 20:00:00     -13.8               -16.5           80
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# Date/Time
# 2012-01-03 19:00:00               24             25.0           101.74   Clear
# ...

# %%
# finding 'Wind Spd'
wthr[wthr['Wind Spd (km/h)'] == 4]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-05 00:00:00      -8.8               -11.7           79
# 2012-01-05 05:00:00      -7.0                -9.5           82
# 2012-01-07 02:00:00      -8.1               -11.1           79
# ...                       ...                 ...          ...
# 2012-12-31 08:00:00      -8.6               -10.3           87
# 2012-12-31 09:00:00      -8.1                -9.6           89
# 2012-12-31 10:00:00      -7.4                -8.9           89
# 2012-12-31 12:00:00      -5.8                -7.5           88
# 2012-12-31 13:00:00      -4.6                -6.6           86
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# ...

# %%
(wthr['Wind Spd (km/h)'] == 4).value_counts()
# Out:
# False    8310
# True      474
# Name: Wind Spd (km/h), dtype: int64

# %%
wthr.isnull().sum()
# Out:
# Temp (C)              0
# Dew Point Temp (C)    0
# Rel Hum (%)           0
# Wind Spd (km/h)       0
# Visibility (km)       0
# Stn Press (kPa)       0
# Weather               0
# dtype: int64

# %%
wthr.notnull().sum()
# Out:
# Temp (C)              8784
# Dew Point Temp (C)    8784
# Rel Hum (%)           8784
# Wind Spd (km/h)       8784
# Visibility (km)       8784
# Stn Press (kPa)       8784
# Weather               8784
# dtype: int64

# %%
# renaming Weather column
wthr.rename(columns={'Weather':'Weather Condition'})
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# ...                       ...                 ...          ...
# 2012-12-31 19:00:00       0.1                -2.7           81
# 2012-12-31 20:00:00       0.2                -2.4           83
# 2012-12-31 21:00:00      -0.5                -1.5           93
# 2012-12-31 22:00:00      -0.2                -1.8           89
# 2012-12-31 23:00:00       0.0                -2.1           86
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# ...

# %%
wthr['Visibility (km)'].mean()
# Out:
# 27.664446721311478

# %%
wthr['Stn Press (kPa)'].std()
# Out:
# 0.8440047459486483

# %%
wthr['Rel Hum (%)'].var()
# Out:
# 286.24855019850196

# %%
 wthr['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# filter Weather column for string values
wthr[wthr['Weather'].str.contains('Snow')]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-02 17:00:00      -2.1                -9.5           57
# 2012-01-02 20:00:00      -5.6               -13.4           54
# 2012-01-02 21:00:00      -5.8               -12.8           58
# 2012-01-02 23:00:00      -7.4               -14.1           59
# 2012-01-03 00:00:00      -9.0               -16.0           57
# ...                       ...                 ...          ...
# 2012-12-31 19:00:00       0.1                -2.7           81
# 2012-12-31 20:00:00       0.2                -2.4           83
# 2012-12-31 21:00:00      -0.5                -1.5           93
# 2012-12-31 22:00:00      -0.2                -1.8           89
# 2012-12-31 23:00:00       0.0                -2.1           86
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-02 17:00:00               22             25.0            99.66
# ...

# %%
# filtering data conditionally
wthr[(wthr['Wind Spd (km/h)'] > 24) & (wthr['Visibility (km)'] == 25)]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 23:00:00       5.3                 2.0           79
# 2012-01-02 00:00:00       5.2                 1.5           77
# 2012-01-02 01:00:00       4.6                 0.0           72
# 2012-01-02 02:00:00       3.9                -0.9           71
# 2012-01-02 03:00:00       3.7                -1.5           69
# ...                       ...                 ...          ...
# 2012-12-28 17:00:00      -8.6               -12.0           76
# 2012-12-30 17:00:00     -12.1               -15.8           74
# 2012-12-30 19:00:00     -13.4               -16.5           77
# 2012-12-30 23:00:00     -12.1               -15.1           78
# 2012-12-31 00:00:00     -11.1               -14.4           77
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 23:00:00               30             25.0            99.31
# ...

# %%
wthr.groupby('Weather').mean()
# Out:
#                                           Temp (C)  Dew Point Temp (C)  \
# Weather
# Clear                                     6.825716            0.089367
# Cloudy                                    7.970544            2.375810
# Drizzle                                   7.353659            5.504878
# Drizzle,Fog                               8.067500            7.033750
# Drizzle,Ice Pellets,Fog                   0.400000           -0.700000
# Drizzle,Snow                              1.050000            0.150000
# Drizzle,Snow,Fog                          0.693333            0.120000
# Fog                                       4.303333            3.159333
# Freezing Drizzle                         -5.657143           -8.000000
# Freezing Drizzle,Fog                     -2.533333           -4.183333
# Freezing Drizzle,Haze                    -5.433333           -8.000000
# Freezing Drizzle,Snow                    -5.109091           -7.072727
# ...

# %%
wthr.groupby('Weather').max().head()
# Out:
#                          Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Weather
# Clear                        32.8                20.4           99
# Cloudy                       30.5                22.6           99
# Drizzle                      18.8                17.7           96
# Drizzle,Fog                  19.9                19.1          100
# Drizzle,Ice Pellets,Fog       0.4                -0.7           92
#
#                          Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)
# Weather
# Clear                                 33             48.3           103.63
# Cloudy                                54             48.3           103.65
# Drizzle                               30             25.0           101.56
# Drizzle,Fog                           28              9.7           102.07
# Drizzle,Ice Pellets,Fog               20              4.0           100.79

# %%
wthr.groupby('Weather').min().head()
# Out:
#                          Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Weather
# Clear                       -23.3               -28.5           20
# Cloudy                      -21.4               -26.8           18
# Drizzle                       1.1                -0.2           74
# Drizzle,Fog                   0.0                -1.6           85
# Drizzle,Ice Pellets,Fog       0.4                -0.7           92
#
#                          Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)
# Weather
# Clear                                  0             11.3            99.52
# Cloudy                                 0             11.3            98.39
# Drizzle                                0              6.4            97.84
# Drizzle,Fog                            0              1.0            98.65
# Drizzle,Ice Pellets,Fog               20              4.0           100.79

# %%
wthr[wthr['Weather']=='Fog']
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 04:00:00      -1.5                -3.3           88
# 2012-01-01 05:00:00      -1.4                -3.3           87
# 2012-01-01 06:00:00      -1.5                -3.1           89
# ...                       ...                 ...          ...
# 2012-12-29 04:00:00     -16.0               -17.2           90
# 2012-12-29 05:00:00     -14.8               -15.9           91
# 2012-12-29 06:00:00     -13.8               -15.3           88
# 2012-12-29 07:00:00     -14.8               -16.4           88
# 2012-12-29 10:00:00     -12.0               -13.3           90
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24     Fog
# ...

# %%
# filtering data conditionally
wthr[(wthr['Weather']=='Clear') | (wthr['Visibility (km)'] > 40)]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-03 19:00:00     -16.9               -24.8           50
# 2012-01-05 10:00:00      -6.0               -10.0           73
# 2012-01-05 11:00:00      -5.6               -10.2           70
# 2012-01-05 12:00:00      -4.7                -9.6           69
# 2012-01-05 13:00:00      -4.4                -9.7           66
# ...                       ...                 ...          ...
# 2012-12-30 13:00:00     -12.4               -16.2           73
# 2012-12-30 14:00:00     -11.8               -16.1           70
# 2012-12-30 15:00:00     -11.3               -15.6           70
# 2012-12-30 16:00:00     -11.4               -15.5           72
# 2012-12-30 20:00:00     -13.8               -16.5           80
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-03 19:00:00               24             25.0           101.74
# ...

# %%
# filtering data conditionally
wthr[(wthr['Weather']=='Clear') & (wthr['Rel Hum (%)'] > 50) | (wthr['Visibility (km)'] > 40)]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-05 10:00:00      -6.0               -10.0           73
# 2012-01-05 11:00:00      -5.6               -10.2           70
# 2012-01-05 12:00:00      -4.7                -9.6           69
# 2012-01-05 13:00:00      -4.4                -9.7           66
# 2012-01-05 14:00:00      -5.1               -10.7           65
# ...                       ...                 ...          ...
# 2012-12-30 13:00:00     -12.4               -16.2           73
# 2012-12-30 14:00:00     -11.8               -16.1           70
# 2012-12-30 15:00:00     -11.3               -15.6           70
# 2012-12-30 16:00:00     -11.4               -15.5           72
# 2012-12-30 20:00:00     -13.8               -16.5           80
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-05 10:00:00               17             48.3           100.45
# ...
